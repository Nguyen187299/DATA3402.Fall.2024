# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, max_val):
        self.max_val=max_val
        self.current_val=0

    def count(self):
        if self.current_val<self.max_val:
            self.current_val +=1
            print("Counter increased by 1")
        else:
            print("Error: Increment is above maximum value")

    def reset(self):
        self.current_val=0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, max_val):
        self.__max_val=max_val
        self.__current_val=0

    def count(self):
        if self.__current_val<self.__max_val:
            self.__current_val +=1
            print("Counter increased by 1")
        else:
            print("Error: Increment is above maximum value")

    def reset(self):
        self.__current_val=0

    def check_val(self):
        return self.__current_val

    def check_max(self):
        return self.max_val

    def if_at_max(self):
        if self.__current_val == self.__max_val:
            print("Counter is at maximum value")
        else:
            print("Counter is not at max value")

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        area = self.__length * self.__width
        return area

    def perimeter(self):
        perimeter = 2 * (self.__length + self.__width)
        return perimeter

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_corner(self):
        return (self.__x,self.__y)

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        pi = 3.14
        area = pi * self.__radius**2
        return area

    def perimeter(self):
        pi = 3.14
        perimeter = 2 * pi * self.__radius
        return perimeter

    def get_radius(self):
        return self.__radius

    def get_center(self):
        return (self.__x,self.__y)

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    def area(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def perimeter(self):
        raise NotImplementedError("Must implement this method in the subclass")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__()
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        area = self.__length * self.__width
        return area

    def perimeter(self):
        perimeter = 2 * (self.__length + self.__width)
        return perimeter

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_corner(self):
        return (self.__x,self.__y)

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__()
        self.__radius = radius
        self.__x = x
        self.__y = y
  
    def area(self):
        pi = 3.14
        area = pi * self.__radius**2
        return area

    def perimeter(self):
        pi = 3.14
        perimeter = 2 * pi * self.__radius
        return perimeter

    def get_radius(self):
        return self.__radius

    def get_center(self):
        return (self.__x,self.__y)

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    def __init__(self, side_1, side_2, side_3, x, y):
        self.__side_1 = side_1
        self.__side_2 = side_2
        self.__side_3 = side_3
        self.__x = x
        self.__y = y

    def area(self):
        s = (self.__side_1 + self.__side_2 + self.__side_3) / 2
        return (s * (s - self.__side_1) * (s - self.__side_2) * (s - self.__side_3)) ** 0.5

    def perimeter(self):
        perimeter = self.__side_1 + self.__side_2 + self.__side_3
        return perimeter

    def get_sides(self):
        return (self.__side_1, self.__side_2, self.__side_3)

    def get_vertex(self):
        return (self.__side_1, self.__side_2, self.__side_3)

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Shape:
    def area(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def perimeter(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def parameter_points(self, num_points=16):
        raise NotImplementedError("Must implement this method in the subclass")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__()
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        area = self.__length * self.__width
        return area

    def perimeter(self):
        perimeter = 2 * (self.__length + self.__width)
        return perimeter

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_corner(self):
        return (self.__x,self.__y)

    def parameter_points(self, num_points=16):
        points = []

        for i in range(num_points):
            distance=(i / num_points)*perimeter
            if distance < self.__length:
                x=self.__x + distance
                y=self.__y
            elif distance < self.__length + self.__width:
                x=self.__x + self.__length
                y=self.__y + (distance - self.__length)
            elif distance < 2 * self.__length + self.__width:
                x=self.__x + self.__length - (distance - (self.__length + self.__width))
                y=self.__y + self.__width
            else:
                x=self.__x
                y=self.__y + self.__width - (distance - (2 * self.__length + self.__width))
            
            points.append((x, y))

        return points

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__()
        self.__radius = radius
        self.__x = x
        self.__y = y
  
    def area(self):
        pi = 3.14
        area = pi * self.__radius**2
        return area

    def perimeter(self):
        pi = 3.14
        perimeter = 2 * pi * self.__radius
        return perimeter

    def get_radius(self):
        return self.__radius

    def get_center(self):
        return (self.__x,self.__y)

    def parameter_points(self, num_points=16):
        points = []
        for i in range(num_points):
            angle=(i / num_points) * 2 * math.pi
            x=self.__x + self.__radius * math.cos(angle)
            y=self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

class Triangle(Shape):
    def __init__(self, side_1, side_2, side_3, x, y):
        self.__side_1 = side_1
        self.__side_2 = side_2
        self.__side_3 = side_3
        self.__x = x
        self.__y = y

    def area(self):
        s = (self.__side_1 + self.__side_2 + self.__side_3) / 2
        return (s * (s - self.__side_1) * (s - self.__side_2) * (s - self.__side_3)) ** 0.5

    def perimeter(self):
        perimeter = self.__side_1 + self.__side_2 + self.__side_3
        return perimeter

    def get_sides(self):
        return (self.__side_1, self.__side_2, self.__side_3)

    def get_vertex(self):
        return (self.__side_1, self.__side_2, self.__side_3)

    def parameter_points(self, num_points=16):
        points = []
        lengths=[self.__side_1, self.__side_2, self.__side_3]
        total_length=sum(lengths)

        for i in range(num_points):
            segment_length=(i / num_points) * total_length
            accumulated_length=0
            
            for j in range(3):
                if accumulated_length + lengths[j] >= segment_length:
                    ratio=(segment_length - accumulated_length) / lengths[j]
                    
                    if j == 0:
                        x_start, y_start = self.__x, self.__y
                        x_end, y_end = self.__x + self.__side_1, self.__y
                    elif j == 1:
                        x_start, y_start = self.__x + self.__side_1, self.__y
                        x_end, y_end = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                         self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                    else:
                        x_start, y_start = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                            self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                        x_end, y_end = self.__x, self.__y
                    
                    x = x_start + ratio * (x_end - x_start)
                    y = y_start + ratio * (y_end - y_start)
                    points.append((x, y))
                    break
                
                accumulated_length += lengths[j]

        return points

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape:
    def area(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def perimeter(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def parameter_points(self, num_points=16):
        raise NotImplementedError("Must implement this method in the subclass")

    def contains(self, x, y):
        raise NotImplementedError("Must implement this method in the subclass")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__()
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        area = self.__length * self.__width
        return area

    def perimeter(self):
        perimeter = 2 * (self.__length + self.__width)
        return perimeter

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_corner(self):
        return (self.__x,self.__y)

    def parameter_points(self, num_points=16):
        points = []

        for i in range(num_points):
            distance=(i / num_points)*perimeter
            if distance < self.__length:
                x=self.__x + distance
                y=self.__y
            elif distance < self.__length + self.__width:
                x=self.__x + self.__length
                y=self.__y + (distance - self.__length)
            elif distance < 2 * self.__length + self.__width:
                x=self.__x + self.__length - (distance - (self.__length + self.__width))
                y=self.__y + self.__width
            else:
                x=self.__x
                y=self.__y + self.__width - (distance - (2 * self.__length + self.__width))
            
            points.append((x, y))

        return points

    def contains(self, x, y):
        return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__()
        self.__radius = radius
        self.__x = x
        self.__y = y
  
    def area(self):
        pi = 3.14
        area = pi * self.__radius**2
        return area

    def perimeter(self):
        pi = 3.14
        perimeter = 2 * pi * self.__radius
        return perimeter

    def get_radius(self):
        return self.__radius

    def get_center(self):
        return (self.__x,self.__y)

    def parameter_points(self, num_points=16):
        points = []
        for i in range(num_points):
            angle=(i / num_points) * 2 * math.pi
            x=self.__x + self.__radius * math.cos(angle)
            y=self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        return (x - self.__x) ** 2 + (y - self.__y) ** 2 <= self.__radius ** 2

class Triangle(Shape):
    def __init__(self, side_1, side_2, side_3, x, y):
        self.__side_1 = side_1
        self.__side_2 = side_2
        self.__side_3 = side_3
        self.__x = x
        self.__y = y

    def area(self):
        s = (self.__side_1 + self.__side_2 + self.__side_3) / 2
        return (s * (s - self.__side_1) * (s - self.__side_2) * (s - self.__side_3)) ** 0.5

    def perimeter(self):
        perimeter = self.__side_1 + self.__side_2 + self.__side_3
        return perimeter

    def get_sides(self):
        return (self.__side_1, self.__side_2, self.__side_3)

    def get_vertex(self):
        return (self.__side_1, self.__side_2, self.__side_3)

    def parameter_points(self, num_points=16):
        points = []
        lengths=[self.__side_1, self.__side_2, self.__side_3]
        total_length=sum(lengths)

        for i in range(num_points):
            segment_length=(i / num_points) * total_length
            accumulated_length=0
            
            for j in range(3):
                if accumulated_length + lengths[j] >= segment_length:
                    ratio=(segment_length - accumulated_length) / lengths[j]
                    
                    if j == 0:
                        x_start, y_start = self.__x, self.__y
                        x_end, y_end = self.__x + self.__side_1, self.__y
                    elif j == 1:
                        x_start, y_start = self.__x + self.__side_1, self.__y
                        x_end, y_end = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                         self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                    else:
                        x_start, y_start = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                            self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                        x_end, y_end = self.__x, self.__y
                    
                    x = x_start + ratio * (x_end - x_start)
                    y = y_start + ratio * (y_end - y_start)
                    points.append((x, y))
                    break
                
                accumulated_length += lengths[j]

        return points

    def contains(self, x, y):
        x1,y1=self.__x, self.__y
        x2,y2=self.__x + self.__side_1, self.__y
        x3=self.__x + (self.__side_1 - self.__side_2 / 2)
        y3=self.__y + (self.__side_2 * (3 ** 0.5) / 2)

        A = abs((x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2)) / 2.0)
        A1 = abs((x * (y2 - y3) + x2 * (y3 - y) + x3 * (y - y2)) / 2.0)
        A2 = abs((x1 * (y - y3) + x * (y3 - y1) + x3 * (y1 - y)) / 2.0)
        A3 = abs((x1 * (y2 - y) + x2 * (y - y1) + x * (y1 - y2)) / 2.0)

        return A == A1 + A2 + A3

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape:
    def area(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def perimeter(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def parameter_points(self, num_points=16):
        raise NotImplementedError("Must implement this method in the subclass")

    def overlaps(self, other):
        raise NotImplementedError("Must implement this method in the subclass")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__()
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def overlaps(self, other):
        if isinstance(other, Rectangle):
            return not (self.__x + self.__length < other.__x or
                        self.__x > other.__x + other.__length or
                        self.__y + self.__width < other.__y or
                        self.__y > other.__y + other.__width)
        elif isinstance(other, Circle):
            return other.overlaps(self)
        elif isinstance(other, Triangle):
            return other.overlaps(self)
        return False

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__()
        self.__radius = radius
        self.__x = x
        self.__y = y

    def overlaps(self, other):
        if isinstance(other, Circle):
            distance = ((self.__x - other.__x) ** 2 + (self.__y - other.__y) ** 2) ** 0.5
            return distance < (self.__radius + other.__radius)
        elif isinstance(other, Rectangle):
            return self.overlaps(other)
        elif isinstance(other, Triangle):
            return other.overlaps(self)
        return False

class Triangle(Shape):
    def __init__(self, side_1, side_2, side_3, x, y):
        super().__init__()
        self.__side_1 = side_1
        self.__side_2 = side_2
        self.__side_3 = side_3
        self.__x = x
        self.__y = y

    def overlaps(self, other):
        if isinstance(other, Triangle):
            return (self.contains(other.__x, other.__y) or
                    self.contains(other.__x + other.__side_1, other.__y) or
                    self.contains(other.__x + (other.__side_1 - other.__side_2 / 2),
                                  other.__y + (other.__side_2 * (3 ** 0.5) / 2)) or
                    other.contains(self.__x, self.__y) or
                    other.contains(self.__x + self.__side_1, self.__y) or
                    other.contains(self.__x + (self.__side_1 - self.__side_2 / 2),
                                   self.__y + (self.__side_2 * (3 ** 0.5) / 2)))
        elif isinstance(other, Rectangle):
            return other.overlaps(self)
        elif isinstance(other, Circle):
            return other.overlaps(self)
        return False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
import math

class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for _ in range(height)]

    def set_pixel(self, row, col, char='*'):
        if 0 <= row < self.height and 0 <= col < self.width:
            self.data[row][col] = char

    def clear_canvas(self):
        self.data = [[' '] * self.width for _ in range(self.height)]

    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

    def h_line(self, x1, y1, x2, char='*'):
        for x in range(int(min(x1, x2)), int(max(x1, x2)) + 1):
            self.set_pixel(int(y1), int(x), char)

class Shape:
    def area(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def perimeter(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def parameter_points(self, num_points=16):
        raise NotImplementedError("Must implement this method in the subclass")

    def overlaps(self, other):
        raise NotImplementedError("Must implement this method in the subclass")

    def contains(self, x, y):
        raise NotImplementedError("Must implement this method in the subclass")

    def paint(self, canvas):
        raise NotImplementedError("Must implement this method in the subclass")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__()
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def parameter_points(self, num_points=16):
        points = []
        for i in range(num_points):
            distance = (i / num_points) * self.perimeter()
            if distance < self.__length:
                x = self.__x + distance
                y = self.__y
            elif distance < self.__length + self.__width:
                x = self.__x + self.__length
                y = self.__y + (distance - self.__length)
            elif distance < 2 * self.__length + self.__width:
                x = self.__x + self.__length - (distance - (self.__length + self.__width))
                y = self.__y + self.__width
            else:
                x = self.__x
                y = self.__y + (distance - (2 * self.__length + self.__width))
            points.append((x, y))
        return points

    def contains(self, x, y):
        return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width

    def overlaps(self, other):
        if isinstance(other, Rectangle):
            return not (self.__x + self.__length < other.__x or
                        self.__x > other.__x + other.__length or
                        self.__y + self.__width < other.__y or
                        self.__y > other.__y + other.__width)
        return False

    def paint(self, canvas):
        for i in range(self.__length):
            canvas.set_pixel(self.__y, self.__x + i) 
            canvas.set_pixel(self.__y + self.__width - 1, self.__x + i) 
        for i in range(self.__width):
            canvas.set_pixel(self.__y + i, self.__x) 
            canvas.set_pixel(self.__y + i, self.__x + self.__length - 1)

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__()
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius**2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def parameter_points(self, num_points=16):
        points = []
        for i in range(num_points):
            angle = (i / num_points) * 2 * math.pi
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        return (x - self.__x) ** 2 + (y - self.__y) ** 2 <= self.__radius ** 2

    def overlaps(self, other):
        if isinstance(other, Circle):
            distance = ((self.__x - other.__x) ** 2 + (self.__y - other.__y) ** 2) ** 0.5
            return distance < (self.__radius + other.__radius)
        elif isinstance(other, Rectangle):
            return self.overlaps(other)
        return False

    def paint(self, canvas):
        for angle in range(0, 360, 10):
            rad = angle * (math.pi / 180)
            x = int(self.__x + self.__radius * math.cos(rad))
            y = int(self.__y + self.__radius * math.sin(rad))
            canvas.set_pixel(y, x)

class Triangle(Shape):
    def __init__(self, side_1, side_2, side_3, x, y):
        super().__init__()
        self.__side_1 = side_1
        self.__side_2 = side_2
        self.__side_3 = side_3
        self.__x = x
        self.__y = y

    def area(self):
        s = (self.__side_1 + self.__side_2 + self.__side_3) / 2
        return (s * (s - self.__side_1) * (s - self.__side_2) * (s - self.__side_3)) ** 0.5

    def perimeter(self):
        return self.__side_1 + self.__side_2 + self.__side_3

    def parameter_points(self, num_points=16):
        points = []
        lengths = [self.__side_1, self.__side_2, self.__side_3]
        total_length = sum(lengths)

        for i in range(num_points):
            segment_length = (i / num_points) * total_length
            accumulated_length = 0
            
            for j in range(3):
                if accumulated_length + lengths[j] >= segment_length:
                    ratio = (segment_length - accumulated_length) / lengths[j]
                    
                    if j == 0:
                        x_start, y_start = self.__x, self.__y
                        x_end, y_end = self.__x + self.__side_1, self.__y
                    elif j == 1:
                        x_start, y_start = self.__x + self.__side_1, self.__y
                        x_end, y_end = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                         self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                    else:
                        x_start, y_start = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                            self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                        x_end, y_end = self.__x, self.__y
                    
                    x = x_start + ratio * (x_end - x_start)
                    y = y_start + ratio * (y_end - y_start)
                    points.append((x, y))
                    break
                
                accumulated_length += lengths[j]

        return points

    def contains(self, x, y):
        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__side_1, self.__y
        x3 = self.__x + (self.__side_1 - self.__side_2 / 2)
        y3 = self.__y + (self.__side_2 * (3 ** 0.5) / 2)

        A = abs((x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2)) / 2.0)
        A1 = abs((x * (y2 - y3) + x2 * (y3 - y) + x3 * (y - y2)) / 2.0)
        A2 = abs((x1 * (y - y3) + x * (y3 - y1) + x3 * (y1 - y)) / 2.0)
        A3 = abs((x1 * (y2 - y) + x2 * (y - y1) + x * (y1 - y2)) / 2.0)

        return A == A1 + A2 + A3

    def overlaps(self, other):
        if isinstance(other, Triangle):
            return (self.contains(other.__x, other.__y) or
                    self.contains(other.__x + other.__side_1, other.__y) or
                    self.contains(other.__x + (other.__side_1 - other.__side_2 / 2),
                                  other.__y + (other.__side_2 * (3 ** 0.5) / 2)) or
                    other.contains(self.__x, self.__y) or
                    other.contains(self.__x + self.__side_1, self.__y) or
                    other.contains(self.__x + (self.__side_1 - self.__side_2 / 2),
                                   self.__y + (self.__side_2 * (3 ** 0.5) / 2)))
        return False

    def paint(self, canvas):
        points = [(self.__x, self.__y), 
                  (self.__x + self.__side_1, self.__y), 
                  (self.__x + (self.__side_1 / 2), self.__y + (self.__side_2 * (3 ** 0.5) / 2))]
        
        for i in range(len(points)):
            start = points[i]
            end = points[(i + 1) % len(points)]
            canvas.h_line(start[0], start[1], end[0])

class CompoundShape(Shape):
    def __init__(self, shapes):
        self.shapes = shapes

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)

canvas = Canvas(20, 10)
rect = Rectangle(5, 3, 2, 1)
circle = Circle(3, 15, 5)
triangle = Triangle(5, 5, 5, 10, 8)

compound = CompoundShape([rect, circle, triangle])
compound.paint(canvas)
canvas.display()
# Out:
#
#   *****
#   *   *      ****
#   *****     *    *
#             *    *
#             *    **
#             *    *
#              ****
#           ******

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self, canvas):
        self.canvas = canvas
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)

    def modify_shape(self, index, new_shape):
        if 0 <= index < len(self.shapes):
            self.shapes[index] = new_shape

canvas=Canvas(20, 10)

rect=Rectangle(5, 3, 2, 1) 
circle=Circle(3, 15, 5)  

print("Initial shape")

drawing=RasterDrawing(canvas)
drawing.add_shape(rect)
drawing.add_shape(circle)
drawing.paint()
canvas.display()

print("Modified shape")

new_rect=Rectangle(10, 6, 1, 2)
drawing.modify_shape(0, new_rect)
drawing.paint()
canvas.display()
# Out:
# Initial shape
#
#   *****
#   *   *      ****
#   *****     *    *
#             *    *
#             *    **
#             *    *
#              ****
#                *
#
# Modified shape
#
#
#  **********  ****
#  *        * *    *
#  *        * *    *
#  *        * *    **
#  *        * *    *
#  **********  ****
#                *

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for _ in range(height)]

    def set_pixel(self, row, col, char='*'):
        if 0 <= row < self.height and 0 <= col < self.width:
            self.data[row][col] = char

    def clear_canvas(self):
        self.data = [[' '] * self.width for _ in range(self.height)]

    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

    def h_line(self, x1, y1, x2, char='*'):
        for x in range(int(min(x1, x2)), int(max(x1, x2)) + 1):
            self.set_pixel(int(y1), int(x), char)

class Shape:
    def area(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def perimeter(self):
        raise NotImplementedError("Must implement this method in the subclass")

    def parameter_points(self, num_points=16):
        raise NotImplementedError("Must implement this method in the subclass")

    def overlaps(self, other):
        raise NotImplementedError("Must implement this method in the subclass")

    def contains(self, x, y):
        raise NotImplementedError("Must implement this method in the subclass")

    def paint(self, canvas):
        raise NotImplementedError("Must implement this method in the subclass")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__()
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def parameter_points(self, num_points=16):
        points = []
        for i in range(num_points):
            distance = (i / num_points) * self.perimeter()
            if distance < self.__length:
                x = self.__x + distance
                y = self.__y
            elif distance < self.__length + self.__width:
                x = self.__x + self.__length
                y = self.__y + (distance - self.__length)
            elif distance < 2 * self.__length + self.__width:
                x = self.__x + self.__length - (distance - (self.__length + self.__width))
                y = self.__y + self.__width
            else:
                x = self.__x
                y = self.__y + (distance - (2 * self.__length + self.__width))
            points.append((x, y))
        return points

    def contains(self, x, y):
        return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width

    def overlaps(self, other):
        if isinstance(other, Rectangle):
            return not (self.__x + self.__length < other.__x or
                        self.__x > other.__x + other.__length or
                        self.__y + self.__width < other.__y or
                        self.__y > other.__y + other.__width)
        return False

    def paint(self, canvas):
        for i in range(self.__length):
            canvas.set_pixel(self.__y, self.__x + i) 
            canvas.set_pixel(self.__y + self.__width - 1, self.__x + i) 
        for i in range(self.__width):
            canvas.set_pixel(self.__y + i, self.__x) 
            canvas.set_pixel(self.__y + i, self.__x + self.__length - 1)

    def __repr__(self):
        return f"Rectangle({self.__length}, {self.__width}, {self.__x}, {self.__y})"


class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__()
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius**2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def parameter_points(self, num_points=16):
        points = []
        for i in range(num_points):
            angle = (i / num_points) * 2 * math.pi
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        return (x - self.__x) ** 2 + (y - self.__y) ** 2 <= self.__radius ** 2

    def overlaps(self, other):
        if isinstance(other, Circle):
            distance = ((self.__x - other.__x) ** 2 + (self.__y - other.__y) ** 2) ** 0.5
            return distance < (self.__radius + other.__radius)
        elif isinstance(other, Rectangle):
            return self.overlaps(other)
        return False

    def paint(self, canvas):
        for angle in range(0, 360, 10):
            rad = angle * (math.pi / 180)
            x = int(self.__x + self.__radius * math.cos(rad))
            y = int(self.__y + self.__radius * math.sin(rad))
            canvas.set_pixel(y, x)

    def __repr__(self):
        return f"Circle({self.__radius}, {self.__x}, {self.__y})"


class Triangle(Shape):
    def __init__(self, side_1, side_2, side_3, x, y):
        super().__init__()
        self.__side_1 = side_1
        self.__side_2 = side_2
        self.__side_3 = side_3
        self.__x = x
        self.__y = y

    def area(self):
        s = (self.__side_1 + self.__side_2 + self.__side_3) / 2
        return (s * (s - self.__side_1) * (s - self.__side_2) * (s - self.__side_3)) ** 0.5

    def perimeter(self):
        return self.__side_1 + self.__side_2 + self.__side_3

    def parameter_points(self, num_points=16):
        points = []
        lengths = [self.__side_1, self.__side_2, self.__side_3]
        total_length = sum(lengths)

        for i in range(num_points):
            segment_length = (i / num_points) * total_length
            accumulated_length = 0
            
            for j in range(3):
                if accumulated_length + lengths[j] >= segment_length:
                    ratio = (segment_length - accumulated_length) / lengths[j]
                    
                    if j == 0:
                        x_start, y_start = self.__x, self.__y
                        x_end, y_end = self.__x + self.__side_1, self.__y
                    elif j == 1:
                        x_start, y_start = self.__x + self.__side_1, self.__y
                        x_end, y_end = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                         self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                    else:
                        x_start, y_start = (self.__x + self.__side_1 - self.__side_2 * 0.5, 
                                            self.__y + (self.__side_2 * (3 ** 0.5) / 2))
                        x_end, y_end = self.__x, self.__y
                    
                    x = x_start + ratio * (x_end - x_start)
                    y = y_start + ratio * (y_end - y_start)
                    points.append((x, y))
                    break
                
                accumulated_length += lengths[j]

        return points

    def contains(self, x, y):
        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__side_1, self.__y
        x3 = self.__x + (self.__side_1 - self.__side_2 / 2)
        y3 = self.__y + (self.__side_2 * (3 ** 0.5) / 2)

        A = abs((x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2)) / 2.0)
        A1 = abs((x * (y2 - y3) + x2 * (y3 - y) + x3 * (y - y2)) / 2.0)
        A2 = abs((x1 * (y - y3) + x * (y3 - y1) + x3 * (y1 - y)) / 2.0)
        A3 = abs((x1 * (y2 - y) + x2 * (y - y1) + x * (y1 - y2)) / 2.0)

        return A == A1 + A2 + A3

    def overlaps(self, other):
        if isinstance(other, Triangle):
            return (self.contains(other.__x, other.__y) or
                    self.contains(other.__x + other.__side_1, other.__y) or
                    self.contains(other.__x + (other.__side_1 - other.__side_2 / 2),
                                  other.__y + (other.__side_2 * (3 ** 0.5) / 2)) or
                    other.contains(self.__x, self.__y) or
                    other.contains(self.__x + self.__side_1, self.__y) or
                    other.contains(self.__x + (self.__side_1 - self.__side_2 / 2),
                                   self.__y + (self.__side_2 * (3 ** 0.5) / 2)))
        return False

    def paint(self, canvas):
        points = [(self.__x, self.__y), 
                  (self.__x + self.__side_1, self.__y), 
                  (self.__x + (self.__side_1 / 2), self.__y + (self.__side_2 * (3 ** 0.5) / 2))]
        
        for i in range(len(points)):
            start = points[i]
            end = points[(i + 1) % len(points)]
            canvas.h_line(start[0], start[1], end[0])

    def __repr__(self):
        return f"Triangle({self.__side_1}, {self.__side_2}, {self.__side_3}, {self.__x}, {self.__y})"

class CompoundShape(Shape):
    def __init__(self, shapes):
        self.shapes = shapes

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)

class RasterDrawing:
    def __init__(self, canvas):
        self.canvas = canvas
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)

    def modify_shape(self, index, new_shape):
        if 0 <= index < len(self.shapes):
            self.shapes[index] = new_shape

    def save(self, filename):
        with open(filename, "w") as f:
            for shape in self.shapes:
                f.write(repr(shape) + '\n')

def shape_loader(filename):
    drawing = RasterDrawing(Canvas(20, 10))
    with open(filename, "r") as f:
        for line in f:
            shape = eval(line.strip())
            drawing.add_shape(shape)
    return drawing

canvas=Canvas(20, 10)

rect=Rectangle(5, 3, 2, 1)
circle=Circle(3, 15, 5)
triangle=Triangle(5, 5, 5, 10, 8)
drawing=RasterDrawing(canvas)

drawing.add_shape(rect)
drawing.add_shape(circle)
drawing.add_shape(triangle)
drawing.save("shapes.csv")
loaded_drawing = shape_loader("shapes.csv")

loaded_drawing.paint()
canvas.display()
